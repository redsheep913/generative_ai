# %% [markdown]
# <a href="https://colab.research.google.com/github/redsheep913/generative_ai/blob/main/%E7%94%9F%E6%88%90%E5%BC%8FAI_HW12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fooocus Workflow !
# - 應用情境：貓貓社群平台用圖
# - 先決定主題再使用LLM根據細節調整prompt
# - 調整Fooocus設定
# - 主題：橘白胖胖的虎斑貓

# %% [markdown]
# - A chubby orange and white tabby cat lying in a warm patch of sunlight streaming through a window, indoor setting, soft afternoon light on hardwood floor, peaceful home atmosphere, cozy interior
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - A chubby orange and white tabby cat curled up sleepily in warm sunlight streaming through window, soft pink paw pads visible as cat stretches contentedly, drowsy expression, peaceful afternoon nap, cozy indoor setting
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - A chubby orange and white tabby cat rolling contentedly on sun-warmed hardwood floor, yawning mid-roll, patch of afternoon sunlight, cozy home interior, domestic comfort and security
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Fooocus 執行

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 76.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.0
#     Uninstalling pygit2-1.18.0:
#       Successfully uninstalled pygit2-1.18.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Total 6725 (delta 0), reused 0 (delta 0), pack-reused 6725 (from 1)
# Receiving objects: 100% (6725/6725), 33.33 MiB | 16.46 MiB/s, done.
# Resolving deltas: 100% (3855/3855), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# ...
