# %% [markdown]
# <a href="https://colab.research.google.com/github/redsheep913/generative_ai/blob/main/%E7%94%9F%E6%88%90%E5%BC%8FAI_HW13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 生成式AI_HW13 期末專案發想
# 由於在課程作業中不管是Bing, Stable Diffusion這些文字生成圖的模型中，都會遇到無法正確精確的英文描述來寫prompt，以達到想要生成的圖片，所以想要創建一個可以將中文簡單描述的提示詞，轉換成英文的具體精確的prompt之後，再丟到Stable Diffusion model進行文字圖像生成。

# %% [markdown]
# ### 主題與方向
# - 英文prompt文字生成模型
# - 能夠給予建議並修改成更好的版本
# - 將修改完的prompt使用在圖像生成模型
# - 最終得到生成圖片結果
